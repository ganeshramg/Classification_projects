# %% [markdown]
# # Pump Status Classification and Prediction

# %% [markdown]
# ## Data import, visualization and cleaning

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:/Users/ganes/Data Science/Datasets/sensor.csv')

# %%
data.head()
# Out:
#    Unnamed: 0            timestamp  sensor_00  sensor_01  sensor_02  \
# 0           0  2018-04-01 00:00:00   2.465394   47.09201    53.2118
# 1           1  2018-04-01 00:01:00   2.465394   47.09201    53.2118
# 2           2  2018-04-01 00:02:00   2.444734   47.35243    53.2118
# 3           3  2018-04-01 00:03:00   2.460474   47.09201    53.1684
# 4           4  2018-04-01 00:04:00   2.445718   47.13541    53.2118
#
#    sensor_03  sensor_04  sensor_05  sensor_06  sensor_07  ...  sensor_43  \
# 0  46.310760   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 1  46.310760   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 2  46.397570   638.8889   73.54598   13.32465   16.03733  ...   41.66666
# 3  46.397568   628.1250   76.98898   13.31742   16.24711  ...   40.88541
# 4  46.397568   636.4583   76.58897   13.35359   16.21094  ...   41.40625
#
#    sensor_44  sensor_45  sensor_46  sensor_47  sensor_48  sensor_49  \
# ...

# %%
data.shape
# Out:
# (220320, 55)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'timestamp', 'sensor_00', 'sensor_01', 'sensor_02',
#        'sensor_03', 'sensor_04', 'sensor_05', 'sensor_06', 'sensor_07',
#        'sensor_08', 'sensor_09', 'sensor_10', 'sensor_11', 'sensor_12',
#        'sensor_13', 'sensor_14', 'sensor_15', 'sensor_16', 'sensor_17',
#        'sensor_18', 'sensor_19', 'sensor_20', 'sensor_21', 'sensor_22',
#        'sensor_23', 'sensor_24', 'sensor_25', 'sensor_26', 'sensor_27',
#        'sensor_28', 'sensor_29', 'sensor_30', 'sensor_31', 'sensor_32',
#        'sensor_33', 'sensor_34', 'sensor_35', 'sensor_36', 'sensor_37',
#        'sensor_38', 'sensor_39', 'sensor_40', 'sensor_41', 'sensor_42',
#        'sensor_43', 'sensor_44', 'sensor_45', 'sensor_46', 'sensor_47',
#        'sensor_48', 'sensor_49', 'sensor_50', 'sensor_51', 'machine_status'],
#       dtype='object')

# %%
data = data.drop(['Unnamed: 0'],axis = 1)

# %%
data.columns
# Out:
# Index(['timestamp', 'sensor_00', 'sensor_01', 'sensor_02', 'sensor_03',
#        'sensor_04', 'sensor_05', 'sensor_06', 'sensor_07', 'sensor_08',
#        'sensor_09', 'sensor_10', 'sensor_11', 'sensor_12', 'sensor_13',
#        'sensor_14', 'sensor_15', 'sensor_16', 'sensor_17', 'sensor_18',
#        'sensor_19', 'sensor_20', 'sensor_21', 'sensor_22', 'sensor_23',
#        'sensor_24', 'sensor_25', 'sensor_26', 'sensor_27', 'sensor_28',
#        'sensor_29', 'sensor_30', 'sensor_31', 'sensor_32', 'sensor_33',
#        'sensor_34', 'sensor_35', 'sensor_36', 'sensor_37', 'sensor_38',
#        'sensor_39', 'sensor_40', 'sensor_41', 'sensor_42', 'sensor_43',
#        'sensor_44', 'sensor_45', 'sensor_46', 'sensor_47', 'sensor_48',
#        'sensor_49', 'sensor_50', 'sensor_51', 'machine_status'],
#       dtype='object')

# %%
plt.figure(figsize = (50,50))
sns.heatmap(data.isnull())

# %%
data['sensor_15'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: sensor_15, dtype: float64

# %%
data = data.drop(['sensor_15'], axis = 1)

# %%
plt.figure(figsize = (8,8))
sns.heatmap(data[data.columns[0:5]].isnull())

# %%
data.columns
# Out:
# Index(['timestamp', 'sensor_00', 'sensor_01', 'sensor_02', 'sensor_03',
#        'sensor_04', 'sensor_05', 'sensor_06', 'sensor_07', 'sensor_08',
#        'sensor_09', 'sensor_10', 'sensor_11', 'sensor_12', 'sensor_13',
#        'sensor_14', 'sensor_16', 'sensor_17', 'sensor_18', 'sensor_19',
#        'sensor_20', 'sensor_21', 'sensor_22', 'sensor_23', 'sensor_24',
#        'sensor_25', 'sensor_26', 'sensor_27', 'sensor_28', 'sensor_29',
#        'sensor_30', 'sensor_31', 'sensor_32', 'sensor_33', 'sensor_34',
#        'sensor_35', 'sensor_36', 'sensor_37', 'sensor_38', 'sensor_39',
#        'sensor_40', 'sensor_41', 'sensor_42', 'sensor_43', 'sensor_44',
#        'sensor_45', 'sensor_46', 'sensor_47', 'sensor_48', 'sensor_49',
#        'sensor_50', 'sensor_51', 'machine_status'],
#       dtype='object')

# %%
len(data.columns)
# Out:
# 53

# %%
data = data.drop(['sensor_50'],axis=1)

# %%
data['machine_status'].value_counts()
# Out:
# NORMAL        205836
# RECOVERING     14477
# BROKEN             7
# Name: machine_status, dtype: int64

# %%
data = data.dropna()

# %%
data.shape
# Out:
# (195815, 52)

# %%
sns.heatmap(data.isnull())

# %%
num_cols = data._get_numeric_data().columns

# %%
num_cols
# Out:
# Index(['sensor_00', 'sensor_01', 'sensor_02', 'sensor_03', 'sensor_04',
#        'sensor_05', 'sensor_06', 'sensor_07', 'sensor_08', 'sensor_09',
#        'sensor_10', 'sensor_11', 'sensor_12', 'sensor_13', 'sensor_14',
#        'sensor_16', 'sensor_17', 'sensor_18', 'sensor_19', 'sensor_20',
#        'sensor_21', 'sensor_22', 'sensor_23', 'sensor_24', 'sensor_25',
#        'sensor_26', 'sensor_27', 'sensor_28', 'sensor_29', 'sensor_30',
#        'sensor_31', 'sensor_32', 'sensor_33', 'sensor_34', 'sensor_35',
#        'sensor_36', 'sensor_37', 'sensor_38', 'sensor_39', 'sensor_40',
#        'sensor_41', 'sensor_42', 'sensor_43', 'sensor_44', 'sensor_45',
#        'sensor_46', 'sensor_47', 'sensor_48', 'sensor_49', 'sensor_51'],
#       dtype='object')

# %% [markdown]
# ## Machine Status Dummy

# %%
data['machine_status'].value_counts()
# Out:
# NORMAL        192769
# RECOVERING      3040
# BROKEN             6
# Name: machine_status, dtype: int64

# %%
mac_stat_uniq = list(data['machine_status'].value_counts().index)

# %%
mac_stat_uniq
# Out:
# ['NORMAL', 'RECOVERING', 'BROKEN']

# %%
def mac_status_dummy(col):
    return mac_stat_uniq.index(col)

# %%
data['machine_status'] = data['machine_status'].apply(mac_status_dummy)

# %%
data['machine_status'].value_counts()
# Out:
# 0    192769
# 1      3040
# 2         6
# Name: machine_status, dtype: int64

# %%
data.drop(['timestamp'],axis=1,inplace=True)

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop(['machine_status'],axis=1)

# %%
y = data['machine_status']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=100,stratify=y)

# %%
X_train.shape,y_train.shape
# Out:
# ((137070, 50), (137070,))

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train,y_train)
# Out:
# C:\Users\ganes\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
pred1 = rf.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     57831
#            1       1.00      0.99      0.99       912
#            2       0.00      0.00      0.00         2
#
#     accuracy                           1.00     58745
#    macro avg       0.67      0.66      0.66     58745
# weighted avg       1.00      1.00      1.00     58745
# C:\Users\ganes\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
pred2 = dt.predict(X_test)

# %%
print(classification_report(y_test,pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     57831
#            1       0.99      0.99      0.99       912
#            2       0.00      0.00      0.00         2
#
#     accuracy                           1.00     58745
#    macro avg       0.66      0.66      0.66     58745
# weighted avg       1.00      1.00      1.00     58745

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(X_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
pred3 = gnb.predict(X_test)

# %%
print(classification_report(y_test,pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95     57831
#            1       0.58      0.97      0.72       912
#            2       0.00      0.00      0.00         2
#
#     accuracy                           0.90     58745
#    macro avg       0.53      0.62      0.56     58745
# weighted avg       0.99      0.90      0.95     58745

# %% [markdown]
# ## AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada = AdaBoostClassifier()

# %%
ada.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,
#                    n_estimators=50, random_state=None)

# %%
pred4 = ada.predict(X_test)

# %%
print(classification_report(y_test,pred4))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     57831
#            1       0.92      0.71      0.80       912
#            2       0.00      0.00      0.00         2
#
#     accuracy                           0.99     58745
#    macro avg       0.64      0.57      0.60     58745
# weighted avg       0.99      0.99      0.99     58745
# C:\Users\ganes\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ## XGBoost

# %%
from xgboost import XGBClassifier

# %%
xg = XGBClassifier()

# %%
xg.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
pred5 = xg.predict(X_test)

# %%
print(classification_report(y_test,pred5))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     57831
#            1       1.00      1.00      1.00       912
#            2       0.00      0.00      0.00         2
#
#     accuracy                           1.00     58745
#    macro avg       0.67      0.67      0.67     58745
# weighted avg       1.00      1.00      1.00     58745

# %% [markdown]
# # ENd
